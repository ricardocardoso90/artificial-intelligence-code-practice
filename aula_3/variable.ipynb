# %%
import pandas as pd

# %%
dict_vendas = {
  'categoria': ["Masculino", "Feminino", "Infantil", "Casa"],
  'valor': [400000, 600000, 250000, 580000], 
  'quantidade': [3000, 5000, 1500, 2500]
}

# %%
dict_vendas
# Out:
# {'categoria': ['Masculino', 'Feminino', 'Infantil', 'Casa'],
#  'valor': [400000, 600000, 250000, 580000],
#  'quantidade': [3000, 5000, 1500, 2500]}

# %%
df_vendas = pd.DataFrame.from_dict(dict_vendas)

# %%
df_vendas
# Out:
#    categoria   valor  quantidade
# 0  Masculino  400000        3000
# 1   Feminino  600000        5000
# 2   Infantil  250000        1500
# 3       Casa  580000        2500

# %% [markdown]
# ### Gráfico de barras verticais - valores.

# %%
df_vendas.plot.bar(x='categoria', y='valor')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='categoria'>

# %% [markdown]
# ### Gráfico de barras verticais - valores ordenados.

# %%
df_vendas.sort_values('valor', ascending=False).plot.bar(x='categoria', y='valor')
# Out:
# <Axes: xlabel='categoria'>

# %%
df_vendas.sort_values('valor', ascending=False).plot.barh(x='categoria', y='quantidade')
# Out:
# <Axes: ylabel='categoria'>

# %%
df_vendas.sort_values('quantidade').plot.barh(x='categoria', y='quantidade')
# Out:
# <Axes: ylabel='categoria'>

# %% [markdown]
# ### Valores de medidas.

# %%
dict_medidas = {
  'idade': [15, 18, 25, 25, 40, 55, 58, 60, 80],
  'altura': [160, 162, 165, 168, 175, 178, 178, 178, 190],
  }

# %%
df_medidas = pd.DataFrame.from_dict(dict_medidas)

# %%
df_medidas
# Out:
#    idade  altura
# 0     15     160
# 1     18     162
# 2     25     165
# 3     25     168
# 4     40     175
# 5     55     178
# 6     58     178
# 7     60     178
# 8     80     190

# %%
df_medidas.plot.scatter(x='idade', y='altura')
# Out:
# <Axes: xlabel='idade', ylabel='altura'>

# %%
df_medidas.plot.scatter(x='idade', y='altura', c='idade', colormap='viridis')
# Out:
# <Axes: xlabel='idade', ylabel='altura'>

# %%
df_medidas.plot.hexbin(x='idade', y='altura', gridsize=10)
# Out:
# <Axes: xlabel='idade', ylabel='altura'>
